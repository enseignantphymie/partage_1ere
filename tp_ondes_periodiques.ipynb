# %% [markdown]
# # MODELISER UNE ONDE AVEC PYTHON

# %% [markdown]
# ### Objectifs du TP : Déterminer les paramètres qui influencent la représentation d’une ondes mécanique progressive périodique

# %% [markdown]
# #### Travail à faire : Se placer sur les parties codées et executer les commandes (cellule en haut "Executer") puis répondre aux questions

# %%
import numpy as np 
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation

# %%
fig, ax = plt.subplots(figsize=(10, 5))
ax.set(xlim=(0,3), ylim=(-1, 1))
plt.xlabel('X (cm)', fontsize=16)
plt.ylabel('Y',fontsize=16,rotation = 'horizontal')
x = np.linspace(0,3,300)
t = np.linspace(1,2,300)
X2,T2 = np.meshgrid(x,t)

#Paramètres de l'onde
A = 0.9
v = 2 # en cm/s
T = 0.25 # en s
k = 2*np.pi/(v*T) # vecteur de l'onde

F = A*np.sin(2*np.pi/T*T2-k*X2) # F fct de 2 variables
line = ax.plot(x,F[0,:], color='r',lw=2)[0]

def animate(i):
    line.set_ydata(F[i,:])
    line.set_xdata(x)
anim = FuncAnimation(fig, animate, interval=50, frames=300)
plt.show()

# %% [markdown]
# #### Travail à faire : Répondre à la question 3 du TP

# %% [markdown]
# #### Travail à faire : Examiner le code ci-dessus. Indiquer dans quelles variables la valeur de l’amplitude de l’onde et de la période temporelle de l’onde sont stockées

# %% [markdown]
# #### Travail à faire : En modifiant (puis en exécutant le code ci-dessous) la valeur de la période temporelle et celle de l’amplitude de l’onde (attention l’amplitude doit être ici inférieure à 1 sinon l’image sera tronquée), étudier leur influence sur la représentation de l’onde

# %%
fig, ax = plt.subplots(figsize=(10, 5))
ax.set(xlim=(0,3), ylim=(-1, 1))
plt.xlabel('X (cm)', fontsize=16)
plt.ylabel('Y',fontsize=16,rotation = 'horizontal')
x = np.linspace(0,3,300)
t = np.linspace(1,2,300)
X2,T2 = np.meshgrid(x,t)

#Paramètres de l'onde
A = 
v = 2 # en cm/s
T =     # en s
k = 2*np.pi/(v*T) # vecteur de l'onde

F = A*np.sin(2*np.pi/T*T2-k*X2) # F fct de 2 variables
line = ax.plot(x,F[0,:], color='r',lw=2)[0]

def animate(i):
    line.set_ydata(F[i,:])
    line.set_xdata(x)
anim = FuncAnimation(fig, animate, interval=50, frames=300)
plt.show()

# %% [markdown]
# #### Travail à faire : Répondre aux questions 6 à 9 du TP
